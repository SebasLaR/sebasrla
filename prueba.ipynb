# %%
import pandas as pd
import os
import unzip
import zipfile

# %%
os.environ["KAGGLE_CONFIG_DIR"] = "."
# !kaggle datasets download -d javagarm/fifa-19-complete-player-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/javagarm/fifa-19-complete-player-dataset
# License(s): CC-BY-NC-SA-4.0
# fifa-19-complete-player-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
with zipfile.ZipFile("fifa-19-complete-player-dataset.zip", 'r') as zip_ref:
    zip_ref.extractall("fifa_data")

# %%
df = pd.read_csv(r"C:\Users\Sebastian\Desktop\prueba_tecnica\fifa_data\kl.csv", encoding='latin1')

# %%
df.describe().T
# Out:
#                             count           mean           std    min  \
# Unnamed: 0                18207.0    9103.000000   5256.052511    0.0
# ID                        18207.0  214298.338606  29965.244204   16.0
# Age                       18206.0      25.122048      4.670022   16.0
# Overall                   18206.0      66.237449      6.907059   46.0
# Potential                 18207.0      71.307299      6.136496   48.0
# Special                   18207.0    1597.809908    272.586016  731.0
# International Reputation  18159.0       1.113222      0.394031    1.0
# Weak Foot                 18159.0       2.947299      0.660456    1.0
# Skill Moves               18159.0       2.361308      0.756164    1.0
# Jersey Number             18147.0      19.546096     15.947765    1.0
# Crossing                  18159.0      49.734181     18.364524    5.0
# Finishing                 18159.0      45.550911     19.525820    2.0
# ...

# %%
df.isnull().any()
df.columns
# df = df.drop(['Unnamed: 0'], axis=1)
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df[df.isnull().sum(axis=1) > 50]
# Out:
#        Unnamed: 0      ID            Name   Age  \
# 13236       13236  177971      J. McNulty  33.0
# 13237       13237  195380      J. Barrera  29.0
# 13238       13238  139317        J. Stead  35.0
# 13239       13239  240437     A. Semprini  20.0
# 13240       13240  209462      R. Bingham  24.0
# 13241       13241  219702    K. Dankowski  21.0
# 13242       13242  225590       I. Colman  23.0
# 13243       13243  233782       M. Feeney  19.0
# 13244       13244  239158        R. Minor  30.0
# 13245       13245  242998          Klauss  21.0
# 13246       13246  244022      I. Sissoko  22.0
# 13247       13247  189238         F. Hart  28.0
# 13248       13248  211511   L. McCullough  24.0
# 13249       13249  224055       Li Yunqiu  27.0
# 13250       13250  244535       F. Garcia  29.0
# 13251       13251  134968    R. Haemhouts  34.0
# 13252       13252  225336       E. Binaku  22.0
# 13253       13253  171320       G. Miller  31.0
# ...

# %%
def clean_data(df):
    # Eliminar las columnas: 'Flag', 'Photo', 'Club Logo'
    df = df.drop(columns=['Flag', 'Photo', 'Club Logo'])
    return df

df = clean_data(df)
